% %%
f = 60 % Hz
w = 2 * pi * f
% Out:
% f =  60
% w =  376.99

% %%
t=0:0.001:0.03;
v_t = 100 * cos(w*t + 0);
plot(t,v_t)
hold on
i_t = 100 * cos(w*t - pi/2);
I = 100 * cos(-pi/2) + 100 * sin(-pi/2) * i
plot(t,i_t)
% Out:
% I =  6.1230e-15 - 1.0000e+02i
