% %% [markdown]
% # 2.1 Motor de Corrente Contínua - Fundamentos
% Capítulo 8 do Chapman 5a Edição

% %% [markdown]
% ## Tarefa
% Resolva os seguintes problemas

% %% [markdown]
% 1.	Um motor CC possui uma resistência equivalente no circuito da armadura de 0,5 Ohm. A 500 rpm o motor desenvolve um conjugado interno de 600 Nm para uma corrente na armadura de 50 A na rotação nominal. Considere a curva de saturação do campo como uma linha reta para correntes abaixo da carga nominal e a tensão da fonte constante. Calcule a corrente da armadura e a nova rotação quando o conjugado/torque interno cai para 250 Nm e o campo é alimentado em:
%
% a) Série
%
% b) Paralelo

% %% [markdown]
% 2. A figura abaixo mostra um motor de corrente contínua, acoplado a uma polia que puxa um elevador a velocidade constante. a) Qual seria a mínima potência motora que recomendaria? b) Qual o valor da eficiência do motor?
% ![2.1.png](attachment:2.1.png)
%
% Dica: Faz-se uma equação de P_int = Tint . w = e_a . i_a e outra que vem da lei de Kirchhoff (malha de tensão), resultado em duas equações envolvendo e_a e i_a. Isola-se da segunda e substitui-se na primeira. Chega-se a uma equação de segundo grau, apresentando duas respostas, sendo uma esdrúxula. Depois calcula-se a eficiência que é a razão entre a potência mecânica desenvolvida e a elétrica de entrada...

% %% [markdown]
% 3.	Uma fresadora demanda a mesma potência mecânica, independente da velocidade. Em um ponto de operação, mediu-se um torque de 30 N.m a uma rotação do motor de 200 rad/s. Nessa condição o motor de corrente contínua de imã permanente apresenta uma força contra-eletromotriz de 400 V, uma perda mecânica por atrito e ventilação de 600 W e uma resistência de armadura de 2,5 ohms. Considere que as perdas mecânicas variam linearmente com a velocidade dentro da faixa de operação. Despreze as perdas magnéticas e determine para a condição de carga de 10 N.m: a potência interna desenvolvida pelo motor, a corrente de armadura, a tensão de alimentação e o rendimento.

% %% [markdown]
% 4. Um motor de cc de excitação independente apresenta potência de saída igual a 1 HP, resistência da armadura de 1 Ohm, resistência do campo de 500 Ohms, quando alimentado a armadura com 200V e o campo com 100 V. Nessa condição, o motor apresentou uma eficiência de 90% a uma velocidade de 100 rad/s. Considere que alimenta-se uma serra, portanto o torque é proporcional a velocidade e que a perda por atrito e ventilação também seja proporcional a velocidade. Para operar a 50 rad/s, qual deve ser a nova tensão de alimentação do campo? Compare o rendimento do motor.

% %% [markdown]
% 5. Recalcule o exercício anterior (10) no caso do motor ser alimentado na armadura por uma fonte de corrente de valor igual a $i_a$. Ou seja, não varie a sua corrente quando variar a força contra eletromotriz.
